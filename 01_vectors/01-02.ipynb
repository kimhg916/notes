# %% [markdown]
# # 1.2: Basics of sets and real numbers
#
# To begin studying mathematics at the university level, we really need to know about sets.
#
# ## Definition of sets
#
# **Sets** are collections of distinct objects. Quite often these objects will be numbers. For example,
#
# $$ A = \left\{ 2,4,6,8\right\} $$
#
# is the set of all even numbers between 2 and 8. The numbers 2, 4, 6, 8 are called **elements** of the set $A$. Here we're describing the set by writing down every element inside curly bracelets.
#
# Objects don't always need to be numbers. We can have a set of colors that the cone cells in our eyes can detect:
# $$ B = \left\{ \text{red, green, blue}\right\}.$$
#
# The colors red, green, and blue are the elements of set $B$.

# %% [markdown]
# ## Membership of sets
#
# To denote that objects belong to sets, we use the symbol $\in$. For example, recall that the number 4 is an element of the set $A$, and that red is an element of $B$. We denote this as
# $$ 4 \in A,\ \text{red} \in B.$$
# If an object does not belong to a set, we write down the crossed-out version of the symbol above. The number 5 and the color yellow are not elements of $A$ and $B$, so we write
# $$ 5 \not \in A,\ \text{yellow}\not\in B.$$

# %% [markdown]
# ## Set-builder notation
#
# So far we've only looked at denoting sets by writing down all of their elements, which is called the _enumerative notation_. This is often not very practical for our purposes, which is why we'll now see a different notation called _set-builder notation_.
#
# Suppose we want to define the set $C$ as the collection of all numbers in $A$ multiplied by 3. We could use the enumerative notation to write down all the elements
# $$ C = \left\{6,12,18,24\right\}.$$
#
# The set-builder notation for $C$ is given by
# $$ C = \left\{ 3x: x\in A\right\}.$$
#
# There are two pieces of information here. The "$3x$", written on the left of the colon, denotes the elements of $C$. The "$x\in A$", on the right of the colon, denotes the condition on the variable $x$. Hence we can interpret the notation above as saying:
#
# $$ \text{``the set $C$ consists of numbers $3x$, where $x$ is an element of $A$''.} $$
#
# More examples need to be added.

# %% [markdown]
# ## The real numbers $\mathbb{R}$
#
# There is one set we will see most frequently in this course: the set of **real numbers**. This set is denoted by $\mathbb{R}$.
#
# The real numbers are the collection of every number we've ever learned in school, which includes:
# * integers $-2,-1,0,1,2,\ldots$
# * fractions $-\frac{3}{2}, \frac{1}{4},\ldots$
# * irrational numbers $\sqrt{2}, -\sqrt{3}, \ldots$.
#
# Let's practice with the set-builder notation we've just learned. Suppose the set $I$ is defined to be the collection of all real numbers that are bigger than zero, i.e. the set of _positive numbers_. How would it be denoted using set-builder notation? We would write down something like:
# $$ I = \left\{ x: x\in \mathbb{R},\ x > 0\right\}.$$
#
# How about the set $J$ of real numbers between zero and one? We would write down
# $$ J = \left\{ x: x\in \mathbb{R},\ 0\leq x\leq 1\right\}.$$
